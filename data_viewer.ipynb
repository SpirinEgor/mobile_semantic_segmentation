# %%
import matplotlib.pyplot as plt

from data_worker import DataWorker
from utils import segmentation_plot

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
data = DataWorker('data')
data.train_shape, data.test_shape
# Out:
# loading annotations into memory...
# Done (t=7.96s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.22s)
# creating index...
# index created!
# (64115, 2693)

# %%
image, mask = data.load_image_mask(data.train_images[0])
segmentation_plot(image, mask).show()

# %%
batch_gen = data.batch_generator(data.train_images, batch_size=10, height=512, width=512, seed=7)
cur_batch = next(batch_gen)
segmentation_plot(cur_batch[0][0], cur_batch[1][0]).show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
